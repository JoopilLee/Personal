# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder

ratings = pd.read_csv('/content/drive/MyDrive/개인화추천시스템/추천시스템 Termproject/BX-Book-Ratings.csv')

ratings['Book-Rating'] = ratings['Book-Rating'].astype(int)
ratings.columns=['user_id','isbn','rating']
ratings=ratings[ratings['rating']!=0]

# %%
from sklearn.utils import shuffle

# User encoding
user_dict = {}
for i in set(ratings['user_id']):
    user_dict[i] = len(user_dict)
n_user = len(user_dict)
# Item encoding
item_dict = {}
start_point = n_user
for i in set(ratings['isbn']):
    item_dict[i] = start_point + len(item_dict)
n_item = len(item_dict)
start_point += n_item
num_x = start_point               # Total number of x
x = shuffle(ratings, random_state=12)

# Generate X data
data = []
y = []
w0 = np.mean(x['rating'])
for i in range(len(ratings)):
    case = x.iloc[i]
    x_index = []
    x_value = []
    x_index.append(user_dict[case['user_id']])     # User id encoding
    x_value.append(1)
    x_index.append(item_dict[case['isbn']])    # Movie id encoding
    x_value.append(1)
    data.append([x_index, x_value])
    y.append(case['rating'] - w0)
    if (i % 10000) == 0:
        print('Encoding ', i, ' cases...')

def RMSE(y_true, y_pred):
    return np.sqrt(np.mean((np.array(y_true) - np.array(y_pred))**2))
# Out:
# Encoding  0  cases...
# Encoding  10000  cases...
# Encoding  20000  cases...
# Encoding  30000  cases...

# %%
class FM():
    def __init__(self, N, K, data, y, alpha, beta, train_ratio=0.7, iterations=100, tolerance=0.005, l2_reg=True, verbose=True):
        self.K = K          # Number of latent factors
        self.N = N          # Number of x (variables)
        self.n_cases = len(data)            # N of observations
        self.alpha = alpha
        self.beta = beta
        self.iterations = iterations
        self.l2_reg = l2_reg
        self.tolerance = tolerance
        self.verbose = verbose
        # w 초기화
        self.w = np.random.normal(scale=1./self.N, size=(self.N))
        # v 초기화
        self.v = np.random.normal(scale=1./self.K, size=(self.N, self.K))
        # Train/Test 분리
        cutoff = int(train_ratio * len(data))
        self.train_x = data[:cutoff]
        self.test_x = data[cutoff:]
        self.train_y = y[:cutoff]
        self.test_y = y[cutoff:]

    def test(self):                                     # Training 하면서 RMSE 계산
        # SGD를 iterations 숫자만큼 수행
        best_RMSE = 10000
        best_iteration = 0
        training_process = []
        for i in range(self.iterations):
            rmse1 = self.sgd(self.train_x, self.train_y)        # SGD & Train RMSE 계산
            rmse2 = self.test_rmse(self.test_x, self.test_y)    # Test RMSE 계산
            training_process.append((i, rmse1, rmse2))
            if self.verbose:
                if (i+1) % 10 == 0:
                    print("Iteration: %d ; Train RMSE = %.6f ; Test RMSE = %.6f" % (i+1, rmse1, rmse2))
            if best_RMSE > rmse2:                       # New best record
                best_RMSE = rmse2
                best_iteration = i
            elif (rmse2 - best_RMSE) > self.tolerance:  # RMSE is increasing over tolerance
                break
        print(best_iteration, best_RMSE)
        return training_process

    # w, v 업데이트를 위한 Stochastic gradient descent
    def sgd(self, x_data, y_data):
        y_pred = []
        for data, y in zip(x_data, y_data):
            x_idx = data[0]
            x_0 = np.array(data[1])     # xi axis=0 [1, 2, 3]
            x_1 = x_0.reshape(-1, 1)    # xi axis=1 [[1], [2], [3]]

            # biases
            bias_score = np.sum(self.w[x_idx] * x_0)

            # score 계산
            vx = self.v[x_idx] * (x_1)          # v matrix * x
            sum_vx = np.sum(vx, axis=0)         # sigma(vx)
            sum_vx_2 = np.sum(vx * vx, axis=0)  # ( v matrix * x )의 제곱
            latent_score = 0.5 * np.sum(np.square(sum_vx) - sum_vx_2)

            # 예측값 계산
            y_hat = bias_score + latent_score
            y_pred.append(y_hat)
            error = y - y_hat
            # w, v 업데이트
            if self.l2_reg:     # regularization이 있는 경우
                self.w[x_idx] += error * self.alpha * (x_0 - self.beta * self.w[x_idx])
                self.v[x_idx] += error * self.alpha * ((x_1) * sum(vx) - (vx * x_1) - self.beta * self.v[x_idx])
            else:               # regularization이 없는 경우
                self.w[x_idx] += error * self.alpha * x_0
                self.v[x_idx] += error * self.alpha * ((x_1) * sum(vx) - (vx * x_1))
        return RMSE(y_data, y_pred)

    def test_rmse(self, x_data, y_data):
        y_pred = []
        for data , y in zip(x_data, y_data):
            y_hat = self.predict(data[0], data[1])
            y_pred.append(y_hat)
        return RMSE(y_data, y_pred)

    def predict(self, idx, x):
        x_0 = np.array(x)
        x_1 = x_0.reshape(-1, 1)

        # biases
        bias_score = np.sum(self.w[idx] * x_0)

        # score 계산
        vx = self.v[idx] * (x_1)
        sum_vx = np.sum(vx, axis=0)
        sum_vx_2 = np.sum(vx * vx, axis=0)
        latent_score = 0.5 * np.sum(np.square(sum_vx) - sum_vx_2)

        # 예측값 계산
        y_hat = bias_score + latent_score
        return y_hat

    def predict_one(self, user_id, movie_id):
        x_idx = np.array([user_dict[user_id], item_dict[movie_id]])
        x_data = np.array([1, 1])
        return self.predict(x_idx, x_data) + w0

# %%
K = 30
# Define the number of folds
num_folds = 3
kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Initialize a list to store the RMSE for each fold
cv_rmse_scores = []

# Perform cross-validation
for fold, (train_idx, val_idx) in enumerate(kf.split(data)):
    print(f"\nFold {fold + 1}/{num_folds}")
    # Convert indices to numpy arrays
    train_idx, val_idx = np.array(train_idx), np.array(val_idx)

    # Split the data into train and validation sets
    train_data, val_data = np.array(data)[train_idx], np.array(data)[val_idx]
    train_y, val_y = np.array(y)[train_idx], np.array(y)[val_idx]

    # Reset the model for each fold
    fm_model = FM(num_x, K, train_data, train_y, alpha=0.002, beta=0.01, train_ratio=0.7, iterations=600, tolerance=0.0005, l2_reg=True, verbose=True)

    # Train the model on the training set
    training_process = fm_model.test()

    # Test the model on the validation set
    val_rmse = fm_model.test_rmse(val_data, val_y)
    print(f"Validation RMSE for Fold {fold + 1}: {val_rmse}")

    # Store the RMSE for this fold
    cv_rmse_scores.append(val_rmse)

# Calculate and print the average RMSE across all folds
average_rmse = np.mean(cv_rmse_scores)
print(f"\nAverage RMSE across K={K}: {average_rmse}")
# Out:
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.694849 ; Test RMSE = 1.758323
# Iteration: 20 ; Train RMSE = 1.600693 ; Test RMSE = 1.726475
# Iteration: 30 ; Train RMSE = 1.527200 ; Test RMSE = 1.707665
# Iteration: 40 ; Train RMSE = 1.465229 ; Test RMSE = 1.695346
# Iteration: 50 ; Train RMSE = 1.410686 ; Test RMSE = 1.686932
# Iteration: 60 ; Train RMSE = 1.361139 ; Test RMSE = 1.681084
# Iteration: 70 ; Train RMSE = 1.314866 ; Test RMSE = 1.677009
# Iteration: 80 ; Train RMSE = 1.270519 ; Test RMSE = 1.674198
# Iteration: 90 ; Train RMSE = 1.227027 ; Test RMSE = 1.672310
# Iteration: 100 ; Train RMSE = 1.183649 ; Test RMSE = 1.671111
# Iteration: 110 ; Train RMSE = 1.140044 ; Test RMSE = 1.670436
# Iteration: 120 ; Train RMSE = 1.096215 ; Test RMSE = 1.670174
# Iteration: 130 ; Train RMSE = 1.052369 ; Test RMSE = 1.670243
# Iteration: 140 ; Train RMSE = 1.008809 ; Test RMSE = 1.670589
# 122 1.6701626078426481
# Validation RMSE for Fold 1: 1.673616981838154
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.701432 ; Test RMSE = 1.757996
# Iteration: 20 ; Train RMSE = 1.607191 ; Test RMSE = 1.726203
# Iteration: 30 ; Train RMSE = 1.533764 ; Test RMSE = 1.707560
# Iteration: 40 ; Train RMSE = 1.471891 ; Test RMSE = 1.695476
# Iteration: 50 ; Train RMSE = 1.417424 ; Test RMSE = 1.687324
# Iteration: 60 ; Train RMSE = 1.367928 ; Test RMSE = 1.681750
# Iteration: 70 ; Train RMSE = 1.321724 ; Test RMSE = 1.677966
# Iteration: 80 ; Train RMSE = 1.277527 ; Test RMSE = 1.675473
# Iteration: 90 ; Train RMSE = 1.234326 ; Test RMSE = 1.673940
# Iteration: 100 ; Train RMSE = 1.191387 ; Test RMSE = 1.673145
# Iteration: 110 ; Train RMSE = 1.148291 ; Test RMSE = 1.672930
# Iteration: 120 ; Train RMSE = 1.104922 ; Test RMSE = 1.673184
# 108 1.6729286456261745
# Validation RMSE for Fold 2: 1.6636036800355842
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.688701 ; Test RMSE = 1.749321
# Iteration: 20 ; Train RMSE = 1.595876 ; Test RMSE = 1.716985
# Iteration: 30 ; Train RMSE = 1.523426 ; Test RMSE = 1.697722
# Iteration: 40 ; Train RMSE = 1.462237 ; Test RMSE = 1.684947
# Iteration: 50 ; Train RMSE = 1.408281 ; Test RMSE = 1.676106
# Iteration: 60 ; Train RMSE = 1.359146 ; Test RMSE = 1.669884
# Iteration: 70 ; Train RMSE = 1.313113 ; Test RMSE = 1.665504
# Iteration: 80 ; Train RMSE = 1.268854 ; Test RMSE = 1.662472
# Iteration: 90 ; Train RMSE = 1.225373 ; Test RMSE = 1.660459
# Iteration: 100 ; Train RMSE = 1.182070 ; Test RMSE = 1.659237
# Iteration: 110 ; Train RMSE = 1.138720 ; Test RMSE = 1.658635
# Iteration: 120 ; Train RMSE = 1.095288 ; Test RMSE = 1.658527
# Iteration: 130 ; Train RMSE = 1.051807 ; Test RMSE = 1.658812
# 116 1.6585140822267948
# Validation RMSE for Fold 3: 1.6845533357291123
#
# Average RMSE across K=20: 1.6739246658676168

# %%
from sklearn.model_selection import KFold

K_list=[50,100,150,200,250,300,350,400]
    # Assume data and y are your input data and target variable
    # Create an instance of your FM model (assuming the class is named FM)
for k in K_list:
    K = k
    # Define the number of folds
    num_folds = 3
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

    # Initialize a list to store the RMSE for each fold
    cv_rmse_scores = []

    # Perform cross-validation
    for fold, (train_idx, val_idx) in enumerate(kf.split(data)):
        print(f"\nFold {fold + 1}/{num_folds}")
        # Convert indices to numpy arrays
        train_idx, val_idx = np.array(train_idx), np.array(val_idx)

        # Split the data into train and validation sets
        train_data, val_data = np.array(data)[train_idx], np.array(data)[val_idx]
        train_y, val_y = np.array(y)[train_idx], np.array(y)[val_idx]

        # Reset the model for each fold
        fm_model = FM(num_x, K, train_data, train_y, alpha=0.002, beta=0.01, train_ratio=0.7, iterations=600, tolerance=0.0005, l2_reg=True, verbose=True)

        # Train the model on the training set
        training_process = fm_model.test()

        # Test the model on the validation set
        val_rmse = fm_model.test_rmse(val_data, val_y)
        print(f"Validation RMSE for Fold {fold + 1}: {val_rmse}")

        # Store the RMSE for this fold
        cv_rmse_scores.append(val_rmse)

    # Calculate and print the average RMSE across all folds
    average_rmse = np.mean(cv_rmse_scores)
    print(f"\nAverage RMSE across K={K}: {average_rmse}")
# Out:
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.696594 ; Test RMSE = 1.758256
# Iteration: 20 ; Train RMSE = 1.604366 ; Test RMSE = 1.726372
# Iteration: 30 ; Train RMSE = 1.532858 ; Test RMSE = 1.707537
# Iteration: 40 ; Train RMSE = 1.473071 ; Test RMSE = 1.695205
# Iteration: 50 ; Train RMSE = 1.421057 ; Test RMSE = 1.686793
# Iteration: 60 ; Train RMSE = 1.374543 ; Test RMSE = 1.680966
# Iteration: 70 ; Train RMSE = 1.331984 ; Test RMSE = 1.676929
# Iteration: 80 ; Train RMSE = 1.292198 ; Test RMSE = 1.674176
# Iteration: 90 ; Train RMSE = 1.254219 ; Test RMSE = 1.672365
# Iteration: 100 ; Train RMSE = 1.217270 ; Test RMSE = 1.671260
# Iteration: 110 ; Train RMSE = 1.180791 ; Test RMSE = 1.670693
# Iteration: 120 ; Train RMSE = 1.144414 ; Test RMSE = 1.670543
# Iteration: 130 ; Train RMSE = 1.107897 ; Test RMSE = 1.670719
# 118 1.6705418578342441
# Validation RMSE for Fold 1: 1.6732766107881087
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.703128 ; Test RMSE = 1.757817
# Iteration: 20 ; Train RMSE = 1.610869 ; Test RMSE = 1.725961
# Iteration: 30 ; Train RMSE = 1.539477 ; Test RMSE = 1.707274
# Iteration: 40 ; Train RMSE = 1.479838 ; Test RMSE = 1.695163
# Iteration: 50 ; Train RMSE = 1.427949 ; Test RMSE = 1.687000
# Iteration: 60 ; Train RMSE = 1.381536 ; Test RMSE = 1.681433
# Iteration: 70 ; Train RMSE = 1.339086 ; Test RMSE = 1.677673
# Iteration: 80 ; Train RMSE = 1.299477 ; Test RMSE = 1.675217
# Iteration: 90 ; Train RMSE = 1.261796 ; Test RMSE = 1.673734
# Iteration: 100 ; Train RMSE = 1.225283 ; Test RMSE = 1.672991
# Iteration: 110 ; Train RMSE = 1.189327 ; Test RMSE = 1.672825
# Iteration: 120 ; Train RMSE = 1.153487 ; Test RMSE = 1.673114
# 107 1.6728178799737219
# Validation RMSE for Fold 2: 1.6629321303876943
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.690657 ; Test RMSE = 1.749560
# Iteration: 20 ; Train RMSE = 1.599804 ; Test RMSE = 1.717208
# Iteration: 30 ; Train RMSE = 1.529411 ; Test RMSE = 1.697937
# Iteration: 40 ; Train RMSE = 1.470509 ; Test RMSE = 1.685160
# Iteration: 50 ; Train RMSE = 1.419229 ; Test RMSE = 1.676326
# Iteration: 60 ; Train RMSE = 1.373336 ; Test RMSE = 1.670115
# Iteration: 70 ; Train RMSE = 1.331304 ; Test RMSE = 1.665747
# Iteration: 80 ; Train RMSE = 1.291961 ; Test RMSE = 1.662725
# Iteration: 90 ; Train RMSE = 1.254332 ; Test RMSE = 1.660710
# Iteration: 100 ; Train RMSE = 1.217635 ; Test RMSE = 1.659465
# Iteration: 110 ; Train RMSE = 1.181358 ; Test RMSE = 1.658817
# Iteration: 120 ; Train RMSE = 1.145277 ; Test RMSE = 1.658630
# Iteration: 130 ; Train RMSE = 1.109300 ; Test RMSE = 1.658801
# 119 1.6586304665117986
# Validation RMSE for Fold 3: 1.6848965566218561
#
# Average RMSE across K=50: 1.673701765932553
#
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.697200 ; Test RMSE = 1.758236
# Iteration: 20 ; Train RMSE = 1.605636 ; Test RMSE = 1.726349
# Iteration: 30 ; Train RMSE = 1.534821 ; Test RMSE = 1.707513
# Iteration: 40 ; Train RMSE = 1.475815 ; Test RMSE = 1.695186
# Iteration: 50 ; Train RMSE = 1.424732 ; Test RMSE = 1.686785
# Iteration: 60 ; Train RMSE = 1.379380 ; Test RMSE = 1.680975
# Iteration: 70 ; Train RMSE = 1.338316 ; Test RMSE = 1.676964
# Iteration: 80 ; Train RMSE = 1.300474 ; Test RMSE = 1.674247
# Iteration: 90 ; Train RMSE = 1.264996 ; Test RMSE = 1.672484
# Iteration: 100 ; Train RMSE = 1.231142 ; Test RMSE = 1.671437
# Iteration: 110 ; Train RMSE = 1.198287 ; Test RMSE = 1.670939
# Iteration: 120 ; Train RMSE = 1.165954 ; Test RMSE = 1.670866
# Iteration: 130 ; Train RMSE = 1.133826 ; Test RMSE = 1.671125
# 116 1.6708496119941945
# Validation RMSE for Fold 1: 1.6730018265131958
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.703755 ; Test RMSE = 1.757789
# Iteration: 20 ; Train RMSE = 1.612148 ; Test RMSE = 1.725917
# Iteration: 30 ; Train RMSE = 1.541435 ; Test RMSE = 1.707215
# Iteration: 40 ; Train RMSE = 1.482553 ; Test RMSE = 1.695089
# Iteration: 50 ; Train RMSE = 1.431556 ; Test RMSE = 1.686913
# Iteration: 60 ; Train RMSE = 1.386237 ; Test RMSE = 1.681334
# Iteration: 70 ; Train RMSE = 1.345169 ; Test RMSE = 1.677561
# Iteration: 80 ; Train RMSE = 1.307329 ; Test RMSE = 1.675092
# Iteration: 90 ; Train RMSE = 1.271910 ; Test RMSE = 1.673591
# Iteration: 100 ; Train RMSE = 1.238233 ; Test RMSE = 1.672824
# Iteration: 110 ; Train RMSE = 1.205702 ; Test RMSE = 1.672620
# Iteration: 120 ; Train RMSE = 1.173809 ; Test RMSE = 1.672855
# 108 1.6726189050990103
# Validation RMSE for Fold 2: 1.6633580533762318
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.691234 ; Test RMSE = 1.749580
# Iteration: 20 ; Train RMSE = 1.601034 ; Test RMSE = 1.717213
# Iteration: 30 ; Train RMSE = 1.531321 ; Test RMSE = 1.697928
# Iteration: 40 ; Train RMSE = 1.473182 ; Test RMSE = 1.685142
# Iteration: 50 ; Train RMSE = 1.422802 ; Test RMSE = 1.676305
# Iteration: 60 ; Train RMSE = 1.378020 ; Test RMSE = 1.670098
# Iteration: 70 ; Train RMSE = 1.337402 ; Test RMSE = 1.665741
# Iteration: 80 ; Train RMSE = 1.299884 ; Test RMSE = 1.662737
# Iteration: 90 ; Train RMSE = 1.264597 ; Test RMSE = 1.660749
# Iteration: 100 ; Train RMSE = 1.230808 ; Test RMSE = 1.659540
# Iteration: 110 ; Train RMSE = 1.197953 ; Test RMSE = 1.658938
# Iteration: 120 ; Train RMSE = 1.165701 ; Test RMSE = 1.658812
# Iteration: 130 ; Train RMSE = 1.133921 ; Test RMSE = 1.659055
# 117 1.6588042078102327
# Validation RMSE for Fold 3: 1.6849283205427068
#
# Average RMSE across K=100: 1.6737627334773784
#
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.697406 ; Test RMSE = 1.758230
# Iteration: 20 ; Train RMSE = 1.606060 ; Test RMSE = 1.726336
# Iteration: 30 ; Train RMSE = 1.535473 ; Test RMSE = 1.707494
# Iteration: 40 ; Train RMSE = 1.476719 ; Test RMSE = 1.695161
# Iteration: 50 ; Train RMSE = 1.425934 ; Test RMSE = 1.686755
# Iteration: 60 ; Train RMSE = 1.380950 ; Test RMSE = 1.680943
# Iteration: 70 ; Train RMSE = 1.340357 ; Test RMSE = 1.676932
# Iteration: 80 ; Train RMSE = 1.303131 ; Test RMSE = 1.674216
# Iteration: 90 ; Train RMSE = 1.268465 ; Test RMSE = 1.672458
# Iteration: 100 ; Train RMSE = 1.235664 ; Test RMSE = 1.671420
# Iteration: 110 ; Train RMSE = 1.204119 ; Test RMSE = 1.670936
# Iteration: 120 ; Train RMSE = 1.173323 ; Test RMSE = 1.670883
# Iteration: 130 ; Train RMSE = 1.142906 ; Test RMSE = 1.671172
# 115 1.6708588899838113
# Validation RMSE for Fold 1: 1.673048920781637
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.703950 ; Test RMSE = 1.757793
# Iteration: 20 ; Train RMSE = 1.612564 ; Test RMSE = 1.725920
# Iteration: 30 ; Train RMSE = 1.542081 ; Test RMSE = 1.707217
# Iteration: 40 ; Train RMSE = 1.483457 ; Test RMSE = 1.695092
# Iteration: 50 ; Train RMSE = 1.432765 ; Test RMSE = 1.686918
# Iteration: 60 ; Train RMSE = 1.387823 ; Test RMSE = 1.681343
# Iteration: 70 ; Train RMSE = 1.347237 ; Test RMSE = 1.677576
# Iteration: 80 ; Train RMSE = 1.310025 ; Test RMSE = 1.675115
# Iteration: 90 ; Train RMSE = 1.275430 ; Test RMSE = 1.673624
# Iteration: 100 ; Train RMSE = 1.242826 ; Test RMSE = 1.672868
# Iteration: 110 ; Train RMSE = 1.211649 ; Test RMSE = 1.672677
# Iteration: 120 ; Train RMSE = 1.181387 ; Test RMSE = 1.672926
# 108 1.6726744727519078
# Validation RMSE for Fold 2: 1.6633377762634265
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.691454 ; Test RMSE = 1.749561
# Iteration: 20 ; Train RMSE = 1.601472 ; Test RMSE = 1.717190
# Iteration: 30 ; Train RMSE = 1.531990 ; Test RMSE = 1.697902
# Iteration: 40 ; Train RMSE = 1.474112 ; Test RMSE = 1.685112
# Iteration: 50 ; Train RMSE = 1.424048 ; Test RMSE = 1.676272
# Iteration: 60 ; Train RMSE = 1.379668 ; Test RMSE = 1.670061
# Iteration: 70 ; Train RMSE = 1.339582 ; Test RMSE = 1.665701
# Iteration: 80 ; Train RMSE = 1.302783 ; Test RMSE = 1.662693
# Iteration: 90 ; Train RMSE = 1.268465 ; Test RMSE = 1.660702
# Iteration: 100 ; Train RMSE = 1.235933 ; Test RMSE = 1.659490
# Iteration: 110 ; Train RMSE = 1.204576 ; Test RMSE = 1.658885
# Iteration: 120 ; Train RMSE = 1.173924 ; Test RMSE = 1.658757
# Iteration: 130 ; Train RMSE = 1.143724 ; Test RMSE = 1.659007
# 117 1.6587497589462237
# Validation RMSE for Fold 3: 1.685003694431583
#
# Average RMSE across K=150: 1.6737967971588823
#
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.697507 ; Test RMSE = 1.758238
# Iteration: 20 ; Train RMSE = 1.606272 ; Test RMSE = 1.726344
# Iteration: 30 ; Train RMSE = 1.535801 ; Test RMSE = 1.707502
# Iteration: 40 ; Train RMSE = 1.477180 ; Test RMSE = 1.695170
# Iteration: 50 ; Train RMSE = 1.426557 ; Test RMSE = 1.686766
# Iteration: 60 ; Train RMSE = 1.381779 ; Test RMSE = 1.680955
# Iteration: 70 ; Train RMSE = 1.341460 ; Test RMSE = 1.676946
# Iteration: 80 ; Train RMSE = 1.304611 ; Test RMSE = 1.674233
# Iteration: 90 ; Train RMSE = 1.270464 ; Test RMSE = 1.672476
# Iteration: 100 ; Train RMSE = 1.238374 ; Test RMSE = 1.671438
# Iteration: 110 ; Train RMSE = 1.207759 ; Test RMSE = 1.670951
# Iteration: 120 ; Train RMSE = 1.178091 ; Test RMSE = 1.670893
# Iteration: 130 ; Train RMSE = 1.148917 ; Test RMSE = 1.671174
# 115 1.670871424415351
# Validation RMSE for Fold 1: 1.673081928194012
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.704054 ; Test RMSE = 1.757786
# Iteration: 20 ; Train RMSE = 1.612777 ; Test RMSE = 1.725911
# Iteration: 30 ; Train RMSE = 1.542408 ; Test RMSE = 1.707205
# Iteration: 40 ; Train RMSE = 1.483912 ; Test RMSE = 1.695078
# Iteration: 50 ; Train RMSE = 1.433372 ; Test RMSE = 1.686901
# Iteration: 60 ; Train RMSE = 1.388617 ; Test RMSE = 1.681324
# Iteration: 70 ; Train RMSE = 1.348270 ; Test RMSE = 1.677554
# Iteration: 80 ; Train RMSE = 1.311368 ; Test RMSE = 1.675091
# Iteration: 90 ; Train RMSE = 1.277183 ; Test RMSE = 1.673597
# Iteration: 100 ; Train RMSE = 1.245120 ; Test RMSE = 1.672837
# Iteration: 110 ; Train RMSE = 1.214654 ; Test RMSE = 1.672643
# Iteration: 120 ; Train RMSE = 1.185301 ; Test RMSE = 1.672887
# 108 1.6726406829827174
# Validation RMSE for Fold 2: 1.663380717296503
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.691556 ; Test RMSE = 1.749548
# Iteration: 20 ; Train RMSE = 1.601684 ; Test RMSE = 1.717175
# Iteration: 30 ; Train RMSE = 1.532317 ; Test RMSE = 1.697884
# Iteration: 40 ; Train RMSE = 1.474567 ; Test RMSE = 1.685093
# Iteration: 50 ; Train RMSE = 1.424658 ; Test RMSE = 1.676251
# Iteration: 60 ; Train RMSE = 1.380469 ; Test RMSE = 1.670039
# Iteration: 70 ; Train RMSE = 1.340632 ; Test RMSE = 1.665678
# Iteration: 80 ; Train RMSE = 1.304164 ; Test RMSE = 1.662670
# Iteration: 90 ; Train RMSE = 1.270295 ; Test RMSE = 1.660678
# Iteration: 100 ; Train RMSE = 1.238363 ; Test RMSE = 1.659465
# Iteration: 110 ; Train RMSE = 1.207778 ; Test RMSE = 1.658859
# Iteration: 120 ; Train RMSE = 1.178049 ; Test RMSE = 1.658730
# Iteration: 130 ; Train RMSE = 1.148862 ; Test RMSE = 1.658978
# 117 1.658722561425065
# Validation RMSE for Fold 3: 1.6850027684668092
#
# Average RMSE across K=200: 1.6738218046524416
#
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.697568 ; Test RMSE = 1.758233
# Iteration: 20 ; Train RMSE = 1.606399 ; Test RMSE = 1.726339
# Iteration: 30 ; Train RMSE = 1.535996 ; Test RMSE = 1.707496
# Iteration: 40 ; Train RMSE = 1.477452 ; Test RMSE = 1.695164
# Iteration: 50 ; Train RMSE = 1.426917 ; Test RMSE = 1.686759
# Iteration: 60 ; Train RMSE = 1.382248 ; Test RMSE = 1.680949
# Iteration: 70 ; Train RMSE = 1.342064 ; Test RMSE = 1.676940
# Iteration: 80 ; Train RMSE = 1.305388 ; Test RMSE = 1.674226
# Iteration: 90 ; Train RMSE = 1.271466 ; Test RMSE = 1.672468
# Iteration: 100 ; Train RMSE = 1.239673 ; Test RMSE = 1.671430
# Iteration: 110 ; Train RMSE = 1.209455 ; Test RMSE = 1.670942
# Iteration: 120 ; Train RMSE = 1.180318 ; Test RMSE = 1.670881
# Iteration: 130 ; Train RMSE = 1.151854 ; Test RMSE = 1.671158
# 116 1.6708603113611726
# Validation RMSE for Fold 1: 1.6730976619100517
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.704114 ; Test RMSE = 1.757788
# Iteration: 20 ; Train RMSE = 1.612902 ; Test RMSE = 1.725911
# Iteration: 30 ; Train RMSE = 1.542601 ; Test RMSE = 1.707205
# Iteration: 40 ; Train RMSE = 1.484179 ; Test RMSE = 1.695077
# Iteration: 50 ; Train RMSE = 1.433725 ; Test RMSE = 1.686900
# Iteration: 60 ; Train RMSE = 1.389076 ; Test RMSE = 1.681324
# Iteration: 70 ; Train RMSE = 1.348859 ; Test RMSE = 1.677557
# Iteration: 80 ; Train RMSE = 1.312124 ; Test RMSE = 1.675096
# Iteration: 90 ; Train RMSE = 1.278155 ; Test RMSE = 1.673606
# Iteration: 100 ; Train RMSE = 1.246373 ; Test RMSE = 1.672852
# Iteration: 110 ; Train RMSE = 1.216276 ; Test RMSE = 1.672665
# Iteration: 120 ; Train RMSE = 1.187406 ; Test RMSE = 1.672920
# 108 1.6726625117630456
# Validation RMSE for Fold 2: 1.6633861732488773
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.691618 ; Test RMSE = 1.749545
# Iteration: 20 ; Train RMSE = 1.601812 ; Test RMSE = 1.717172
# Iteration: 30 ; Train RMSE = 1.532516 ; Test RMSE = 1.697881
# Iteration: 40 ; Train RMSE = 1.474846 ; Test RMSE = 1.685090
# Iteration: 50 ; Train RMSE = 1.425033 ; Test RMSE = 1.676249
# Iteration: 60 ; Train RMSE = 1.380966 ; Test RMSE = 1.670039
# Iteration: 70 ; Train RMSE = 1.341287 ; Test RMSE = 1.665681
# Iteration: 80 ; Train RMSE = 1.305034 ; Test RMSE = 1.662677
# Iteration: 90 ; Train RMSE = 1.271457 ; Test RMSE = 1.660691
# Iteration: 100 ; Train RMSE = 1.239924 ; Test RMSE = 1.659486
# Iteration: 110 ; Train RMSE = 1.209868 ; Test RMSE = 1.658889
# Iteration: 120 ; Train RMSE = 1.180799 ; Test RMSE = 1.658774
# Iteration: 130 ; Train RMSE = 1.152373 ; Test RMSE = 1.659040
# 117 1.6587633155114943
# Validation RMSE for Fold 3: 1.6849518266994594
#
# Average RMSE across K=250: 1.6738118872861296
#
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.697609 ; Test RMSE = 1.758228
# Iteration: 20 ; Train RMSE = 1.606484 ; Test RMSE = 1.726333
# Iteration: 30 ; Train RMSE = 1.536128 ; Test RMSE = 1.707490
# Iteration: 40 ; Train RMSE = 1.477636 ; Test RMSE = 1.695157
# Iteration: 50 ; Train RMSE = 1.427164 ; Test RMSE = 1.686753
# Iteration: 60 ; Train RMSE = 1.382574 ; Test RMSE = 1.680943
# Iteration: 70 ; Train RMSE = 1.342493 ; Test RMSE = 1.676936
# Iteration: 80 ; Train RMSE = 1.305955 ; Test RMSE = 1.674225
# Iteration: 90 ; Train RMSE = 1.272222 ; Test RMSE = 1.672471
# Iteration: 100 ; Train RMSE = 1.240687 ; Test RMSE = 1.671437
# Iteration: 110 ; Train RMSE = 1.210816 ; Test RMSE = 1.670955
# Iteration: 120 ; Train RMSE = 1.182128 ; Test RMSE = 1.670903
# Iteration: 130 ; Train RMSE = 1.154209 ; Test RMSE = 1.671189
# 115 1.670878607449421
# Validation RMSE for Fold 1: 1.673069157351757
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.704157 ; Test RMSE = 1.757787
# Iteration: 20 ; Train RMSE = 1.612990 ; Test RMSE = 1.725910
# Iteration: 30 ; Train RMSE = 1.542736 ; Test RMSE = 1.707204
# Iteration: 40 ; Train RMSE = 1.484368 ; Test RMSE = 1.695076
# Iteration: 50 ; Train RMSE = 1.433978 ; Test RMSE = 1.686901
# Iteration: 60 ; Train RMSE = 1.389407 ; Test RMSE = 1.681326
# Iteration: 70 ; Train RMSE = 1.349292 ; Test RMSE = 1.677560
# Iteration: 80 ; Train RMSE = 1.312692 ; Test RMSE = 1.675102
# Iteration: 90 ; Train RMSE = 1.278903 ; Test RMSE = 1.673616
# Iteration: 100 ; Train RMSE = 1.247365 ; Test RMSE = 1.672868
# Iteration: 110 ; Train RMSE = 1.217595 ; Test RMSE = 1.672689
# Iteration: 120 ; Train RMSE = 1.189154 ; Test RMSE = 1.672953
# 108 1.6726848111737762
# Validation RMSE for Fold 2: 1.6634099316412294
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.691656 ; Test RMSE = 1.749551
# Iteration: 20 ; Train RMSE = 1.601892 ; Test RMSE = 1.717177
# Iteration: 30 ; Train RMSE = 1.532639 ; Test RMSE = 1.697886
# Iteration: 40 ; Train RMSE = 1.475019 ; Test RMSE = 1.685095
# Iteration: 50 ; Train RMSE = 1.425262 ; Test RMSE = 1.676253
# Iteration: 60 ; Train RMSE = 1.381265 ; Test RMSE = 1.670043
# Iteration: 70 ; Train RMSE = 1.341676 ; Test RMSE = 1.665686
# Iteration: 80 ; Train RMSE = 1.305540 ; Test RMSE = 1.662683
# Iteration: 90 ; Train RMSE = 1.272121 ; Test RMSE = 1.660697
# Iteration: 100 ; Train RMSE = 1.240802 ; Test RMSE = 1.659493
# Iteration: 110 ; Train RMSE = 1.211032 ; Test RMSE = 1.658899
# Iteration: 120 ; Train RMSE = 1.182331 ; Test RMSE = 1.658786
# Iteration: 130 ; Train RMSE = 1.154350 ; Test RMSE = 1.659055
# 117 1.6587748100869335
# Validation RMSE for Fold 3: 1.684916404192756
#
# Average RMSE across K=300: 1.673798497728581
#
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.697638 ; Test RMSE = 1.758228
# Iteration: 20 ; Train RMSE = 1.606545 ; Test RMSE = 1.726333
# Iteration: 30 ; Train RMSE = 1.536223 ; Test RMSE = 1.707489
# Iteration: 40 ; Train RMSE = 1.477769 ; Test RMSE = 1.695156
# Iteration: 50 ; Train RMSE = 1.427343 ; Test RMSE = 1.686752
# Iteration: 60 ; Train RMSE = 1.382810 ; Test RMSE = 1.680942
# Iteration: 70 ; Train RMSE = 1.342805 ; Test RMSE = 1.676934
# Iteration: 80 ; Train RMSE = 1.306369 ; Test RMSE = 1.674223
# Iteration: 90 ; Train RMSE = 1.272777 ; Test RMSE = 1.672467
# Iteration: 100 ; Train RMSE = 1.241436 ; Test RMSE = 1.671432
# Iteration: 110 ; Train RMSE = 1.211831 ; Test RMSE = 1.670947
# Iteration: 120 ; Train RMSE = 1.183493 ; Test RMSE = 1.670891
# Iteration: 130 ; Train RMSE = 1.156007 ; Test RMSE = 1.671171
# 115 1.6708683988575592
# Validation RMSE for Fold 1: 1.6731368017281845
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.704185 ; Test RMSE = 1.757782
# Iteration: 20 ; Train RMSE = 1.613049 ; Test RMSE = 1.725903
# Iteration: 30 ; Train RMSE = 1.542827 ; Test RMSE = 1.707195
# Iteration: 40 ; Train RMSE = 1.484494 ; Test RMSE = 1.695066
# Iteration: 50 ; Train RMSE = 1.434145 ; Test RMSE = 1.686890
# Iteration: 60 ; Train RMSE = 1.389624 ; Test RMSE = 1.681313
# Iteration: 70 ; Train RMSE = 1.349572 ; Test RMSE = 1.677546
# Iteration: 80 ; Train RMSE = 1.313051 ; Test RMSE = 1.675086
# Iteration: 90 ; Train RMSE = 1.279368 ; Test RMSE = 1.673598
# Iteration: 100 ; Train RMSE = 1.247969 ; Test RMSE = 1.672846
# Iteration: 110 ; Train RMSE = 1.218383 ; Test RMSE = 1.672663
# Iteration: 120 ; Train RMSE = 1.190184 ; Test RMSE = 1.672921
# 108 1.6726593466350423
# Validation RMSE for Fold 2: 1.6634067883189965
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.691689 ; Test RMSE = 1.749548
# Iteration: 20 ; Train RMSE = 1.601958 ; Test RMSE = 1.717172
# Iteration: 30 ; Train RMSE = 1.532740 ; Test RMSE = 1.697879
# Iteration: 40 ; Train RMSE = 1.475158 ; Test RMSE = 1.685087
# Iteration: 50 ; Train RMSE = 1.425448 ; Test RMSE = 1.676244
# Iteration: 60 ; Train RMSE = 1.381510 ; Test RMSE = 1.670033
# Iteration: 70 ; Train RMSE = 1.341998 ; Test RMSE = 1.665674
# Iteration: 80 ; Train RMSE = 1.305967 ; Test RMSE = 1.662669
# Iteration: 90 ; Train RMSE = 1.272691 ; Test RMSE = 1.660682
# Iteration: 100 ; Train RMSE = 1.241570 ; Test RMSE = 1.659476
# Iteration: 110 ; Train RMSE = 1.212067 ; Test RMSE = 1.658878
# Iteration: 120 ; Train RMSE = 1.183706 ; Test RMSE = 1.658762
# Iteration: 130 ; Train RMSE = 1.156123 ; Test RMSE = 1.659028
# 117 1.6587519078250015
# Validation RMSE for Fold 3: 1.6849476602142877
#
# Average RMSE across K=350: 1.673830416753823
#
# Fold 1/3
# Iteration: 10 ; Train RMSE = 1.697662 ; Test RMSE = 1.758229
# Iteration: 20 ; Train RMSE = 1.606593 ; Test RMSE = 1.726333
# Iteration: 30 ; Train RMSE = 1.536295 ; Test RMSE = 1.707490
# Iteration: 40 ; Train RMSE = 1.477869 ; Test RMSE = 1.695156
# Iteration: 50 ; Train RMSE = 1.427478 ; Test RMSE = 1.686752
# Iteration: 60 ; Train RMSE = 1.382988 ; Test RMSE = 1.680942
# Iteration: 70 ; Train RMSE = 1.343041 ; Test RMSE = 1.676934
# Iteration: 80 ; Train RMSE = 1.306684 ; Test RMSE = 1.674224
# Iteration: 90 ; Train RMSE = 1.273204 ; Test RMSE = 1.672470
# Iteration: 100 ; Train RMSE = 1.242021 ; Test RMSE = 1.671435
# Iteration: 110 ; Train RMSE = 1.212636 ; Test RMSE = 1.670953
# Iteration: 120 ; Train RMSE = 1.184588 ; Test RMSE = 1.670898
# Iteration: 130 ; Train RMSE = 1.157454 ; Test RMSE = 1.671181
# 115 1.6708751529020904
# Validation RMSE for Fold 1: 1.673153158789062
#
# Fold 2/3
# Iteration: 10 ; Train RMSE = 1.704209 ; Test RMSE = 1.757784
# Iteration: 20 ; Train RMSE = 1.613097 ; Test RMSE = 1.725906
# Iteration: 30 ; Train RMSE = 1.542900 ; Test RMSE = 1.707199
# Iteration: 40 ; Train RMSE = 1.484594 ; Test RMSE = 1.695071
# Iteration: 50 ; Train RMSE = 1.434278 ; Test RMSE = 1.686895
# Iteration: 60 ; Train RMSE = 1.389798 ; Test RMSE = 1.681320
# Iteration: 70 ; Train RMSE = 1.349796 ; Test RMSE = 1.677555
# Iteration: 80 ; Train RMSE = 1.313341 ; Test RMSE = 1.675097
# Iteration: 90 ; Train RMSE = 1.279744 ; Test RMSE = 1.673612
# Iteration: 100 ; Train RMSE = 1.248460 ; Test RMSE = 1.672865
# Iteration: 110 ; Train RMSE = 1.219028 ; Test RMSE = 1.672687
# Iteration: 120 ; Train RMSE = 1.191035 ; Test RMSE = 1.672952
# 108 1.6726828227963066
# Validation RMSE for Fold 2: 1.6634113112078615
#
# Fold 3/3
# Iteration: 10 ; Train RMSE = 1.691712 ; Test RMSE = 1.749550
# Iteration: 20 ; Train RMSE = 1.602004 ; Test RMSE = 1.717175
# Iteration: 30 ; Train RMSE = 1.532810 ; Test RMSE = 1.697882
# Iteration: 40 ; Train RMSE = 1.475256 ; Test RMSE = 1.685090
# Iteration: 50 ; Train RMSE = 1.425580 ; Test RMSE = 1.676247
# Iteration: 60 ; Train RMSE = 1.381686 ; Test RMSE = 1.670037
# Iteration: 70 ; Train RMSE = 1.342232 ; Test RMSE = 1.665679
# Iteration: 80 ; Train RMSE = 1.306283 ; Test RMSE = 1.662675
# Iteration: 90 ; Train RMSE = 1.273125 ; Test RMSE = 1.660689
# Iteration: 100 ; Train RMSE = 1.242172 ; Test RMSE = 1.659485
# Iteration: 110 ; Train RMSE = 1.212907 ; Test RMSE = 1.658890
# Iteration: 120 ; Train RMSE = 1.184857 ; Test RMSE = 1.658777
# Iteration: 130 ; Train RMSE = 1.157633 ; Test RMSE = 1.659048
# 117 1.6587664718075192
# Validation RMSE for Fold 3: 1.6849445737342463
#
# Average RMSE across K=400: 1.67383634791039
